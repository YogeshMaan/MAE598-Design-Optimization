# %% [markdown]
# <a href="https://colab.research.google.com/github/YogeshMaan/MAE598-Design-Optimization/blob/main/HW5_P2_DesignOptimization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bayesian-optimization

# %%
import numpy as np
from bayes_opt import BayesianOptimization

# Define the cost function (you can replace this with your own function)
def cost_function(x1, x2):
    return -1*((4 - 2.1*(x1**2) + ((x1**4)/3))*(x1**2) + (x1*x2) + (-4 + 4*(x2**2))*(x2**2))

# Set up the optimization space
space = {'x1': (-3.0, 3.0), 'x2': (-2.0, 2.0)} # Bounds for x

# Initialize the optimizer
opt = BayesianOptimization(
    f = cost_function,
    pbounds = space,
    random_state = 11,
    allow_duplicate_points=True)


opt.maximize(init_points = 0, n_iter = 250)


print("Best Parameter:", opt.max['params'])
print("Best Cost:", -opt.max['target'])
# Out:
# |   iter    |  target   |    x1     |    x2     |
# -------------------------------------------------
# | 1         | -46.4     | -1.918    | -1.922    |
# | 2         | -153.3    | 2.998     | 1.916     |
# | 3         | -5.04     | -2.178    | 0.611     |
# | 4         | -150.9    | -3.0      | 2.0       |
# | 5         | -6.32     | -2.216    | 0.5702    |
# | 6         | -2.402    | -1.172    | -0.005301 |
# | 7         | -6.569    | -0.3934   | 1.368     |
# | 8         | -48.24    | 0.9895    | -2.0      |
# | 9         | -0.9446   | 0.5184    | 0.04341   |
# | 10        | -150.9    | 3.0       | -2.0      |
# | 11        | -2.941    | -0.2627   | -1.19     |
# | 12        | -50.78    | 0.677     | 2.0       |
# | 13        | -107.3    | -2.987    | -0.8864   |
# | 14        | -50.22    | -0.569    | -2.0      |
# | 15        | 0.05178   | -0.302    | 0.2917    |
# | 16        | 0.03631   | 0.6531    | -0.8367   |
# | 17        | -45.46    | -1.053    | 1.975     |
# ...
